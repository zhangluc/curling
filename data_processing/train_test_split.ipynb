# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
ends = pd.read_csv("/Users/brentkong/Documents/curling/data_processing/processed_data/bayesian_training.csv")

# %%
test_features = ends[["Has_Hammer", "PowerPlayBool", "EndID", "PrevScoreDiff", "Result"]].copy()

train_df, test_df = train_test_split(test_features, test_size = 0.2, shuffle = True)
train_df.to_csv("/Users/brentkong/Documents/curling/data_processing/train_test_data/train_df.csv", index = False)
test_df.to_csv("/Users/brentkong/Documents/curling/data_processing/train_test_data/test_df.csv", index = False)
