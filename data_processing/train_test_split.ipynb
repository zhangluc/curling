# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
ends = pd.read_csv("/Users/brentkong/Documents/curling/processed_data/ends_processed.csv")

# %%
test_features = ends[[]]
